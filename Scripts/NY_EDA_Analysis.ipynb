# %% [markdown]
# # 1. Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re

# %% [markdown]
# # 2. Loading and Cleaning the NY database

# %%
cd ..
# Out:
# C:\Users\W10\Documents\GitHub\Messy_Data

# %%
cd Data
# Out:
# C:\Users\W10\Documents\GitHub\Messy_Data\Data

# %%
#Load the dataframe
dfNY = pd.read_csv('fulltimeNY.csv')

# %%
dfNY.head()
# Out:
#                                             position  \
# 0  Data Scientist—Research (Ref # EXEC/RD_DAT_NYC...
# 1                  Data Scientist/Pre Sales Engineer
# 2                    Data Analyst/Research Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                                              company  \
# 0  New York State Office of the Attorney General ...
# 1                                            Celonis
# 2                 Columbia University Medical Center
# 3                                   fractalanalytics
# 4                               Blackboard Insurance
#
#                                          description    numreview  \
# 0  <span id="job_summary" class="summary"><p><b>E...          NaN
# 1  <span id="job_summary" class="summary"><p>Celo...          NaN
# 2  <span id="job_summary" class="summary"><p>We a...  217 reviews
# ...

# %%
dfNY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     986 non-null    object
#  1   company      986 non-null    object
#  2   description  986 non-null    object
#  3   numreview    755 non-null    object
#  4   location     986 non-null    object
# dtypes: object(5)
# memory usage: 38.6+ KB

# %% [markdown]
# We have null values in the *numreview* variable, but since we are not intersted in it, we didn't make actions about it.

# %%
dfNY.describe()
# Out:
#               position             company  \
# count              986                 986
# unique             731                 501
# top     Data Scientist  NYU Langone Health
# freq               103                  77
#
#                                               description    numreview  \
# count                                                 986          755
# unique                                                977          190
# top     <span id="job_summary" class="summary"><div><p...  705 reviews
# freq                                                    2           76
#
#             location
# count            986
# unique           115
# top     New York, NY
# freq             503

# %%
dfNY.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are not duplicates. The names of the variables are already standardizes, so the data cleaning is finished and we proceed to the EDA.

# %% [markdown]
# # 3. EDA

# %% [markdown]
# We want to answer our second question:
# - What types of positions are the most required?
#
# We will look into *data analyst*, *data scientist* and *data engineer*. In addition, we will check *junior* and *senior* positions.

# %%
#check the unique entries of the position
dfNY['position'].unique()
# Out:
# array(['data_scientist—research_(ref_#_exec/rd_dat_nyc_6073)',
#        'data_scientist/pre_sales_engineer',
#        'data_analyst/research_scientist', 'data_scientist',
#        'data_analyst_/_data_scientist', 'staff_data_scientist',
#        'clinical_data_assistant_-_ipc', 'data_analytics_specialist',
#        'data_scientist,_supply_chain_analytics',
#        'data_scientist,_analytics',
#        'statistical_analyst/data_scientist_(machine_learning)',
#        'data_visualization_data_scientist',
#        'data_scientist_(data_science_team)',
#        'quantitative_analyst_developer', 'image_processing_scientist',
#        'sales_engineer',
#        'senior_evaluation_coordinator,_new_york_city_teens_connection,_bronx_neighborhood_health_action_center',
#        'director,_data_science', 'clinical_trial_research_analyst',
#        'senior_quantitative_analyst',
#        'senior_associate,_data_scientist/statistics_--_financial_services',
# ...

# %%
#let's standardize the entries of the variable "position"
#make everything in lowercase
dfNY['position'] = dfNY['position'].str.lower()
dfNY['position']
# Out:
# 0      data_scientist—research_(ref_#_exec/rd_dat_nyc...
# 1                      data_scientist/pre_sales_engineer
# 2                        data_analyst/research_scientist
# 3                                         data_scientist
# 4                                         data_scientist
#                              ...
# 981                                       data_scientist
# 982                                junior_data_scientist
# 983                         data_scientist_(entry-level)
# 984                                       data_scientist
# 985                 junior_data_scientist_apprenticeship
# Name: position, Length: 986, dtype: object

# %%
#replace white spaces with underscore
dfNY['position']=dfNY['position'].str.replace(' ','_', regex=True)
dfNY['position']
# Out:
# 0      data_scientist—research_(ref_#_exec/rd_dat_nyc...
# 1                      data_scientist/pre_sales_engineer
# 2                        data_analyst/research_scientist
# 3                                         data_scientist
# 4                                         data_scientist
#                              ...
# 981                                       data_scientist
# 982                                junior_data_scientist
# 983                         data_scientist_(entry-level)
# 984                                       data_scientist
# 985                 junior_data_scientist_apprenticeship
# Name: position, Length: 986, dtype: object
