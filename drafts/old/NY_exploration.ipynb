# %% [markdown]
# Exploration of the file ALLdata.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df1 = pd.read_csv('fulltimeNY.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     986 non-null    object
#  1   company      986 non-null    object
#  2   description  986 non-null    object
#  3   numreview    755 non-null    object
#  4   location     986 non-null    object
# dtypes: object(5)
# memory usage: 38.6+ KB

# %% [markdown]
# There are 5 variables in this dataset. According to 'type', all of them are strings, but the numreview variable is a numerical variables which is read as an object because the entries contain the word "reviews". Since we are not interested in this variable, we are not going yo change it.
#
# There are no null values in any of the variables, except for numreview, which again is not of interest for us, so we are not gonna clean them.

# %%
df1.head(30)
# Out:
#                                              position  \
# 0   Data Scientist—Research (Ref # EXEC/RD_DAT_NYC...
# 1                   Data Scientist/Pre Sales Engineer
# 2                     Data Analyst/Research Scientist
# 3                                      Data Scientist
# 4                                      Data Scientist
# 5                       Data Analyst / Data Scientist
# 6                                Staff Data Scientist
# 7                       Clinical Data Assistant - IPC
# 8                           Data Analytics Specialist
# 9              Data Scientist, Supply Chain Analytics
# 10                          Data Scientist, Analytics
# 11  Statistical Analyst/Data Scientist (Machine Le...
# 12                  Data Visualization Data Scientist
# 13                                     Data Scientist
# 14                 Data Scientist (Data Science Team)
# 15                                     Data Scientist
# ...

# %%
df1.describe()
# Out:
#               position             company  \
# count              986                 986
# unique             731                 501
# top     Data Scientist  NYU Langone Health
# freq               103                  77
#
#                                               description    numreview  \
# count                                                 986          755
# unique                                                977          190
# top     <span id="job_summary" class="summary"><div><p...  705 reviews
# freq                                                    2           76
#
#             location
# count            986
# unique           115
# top     New York, NY
# freq             503

# %%
# Check for duplicates
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are not duplicates.
# The names of the variables are already standardizes, so the data cleaning is finished and we proceed to the EDA.

# %% [markdown]
# What type of positions are most required?
# We will look into data analyst, data scientist and data engineer. In addition, we will check junior and senior positions.

# %%
#check the unique entries of the position
df1['position'].unique()
# Out:
# array(['Data Scientist—Research (Ref # EXEC/RD_DAT_NYC_6073)',
#        'Data Scientist/Pre Sales Engineer',
#        'Data Analyst/Research Scientist', 'Data Scientist',
#        'Data Analyst / Data Scientist', 'Staff Data Scientist',
#        'Clinical Data Assistant - IPC', 'Data Analytics Specialist',
#        'Data Scientist, Supply Chain Analytics',
#        'Data Scientist, Analytics',
#        'Statistical Analyst/Data Scientist (Machine Learning)',
#        'Data Visualization Data Scientist',
#        'Data Scientist (Data Science Team)',
#        'Quantitative Analyst Developer', 'Image Processing Scientist',
#        'Sales Engineer',
#        'Senior Evaluation Coordinator, New York City Teens Connection, Bronx Neighborhood Health Action Center',
#        'Director, Data Science', 'Clinical Trial Research Analyst',
#        'Senior Quantitative Analyst',
#        'Senior Associate, Data Scientist/Statistics -- Financial Services',
# ...

# %%
df1['position'] = df1['position'].str.lower() #make all the strings in the position variables in lowercase

# %%
df1['position']=df1['position'].str.replace(' ','_', regex=True)

# %% [markdown]
# data_scientist = []
# data_engineer = []
# data_analyst = []
#
#
# data_scientist = df1[df1['position'].str.contains('data scientist|machine learning|statistician')]

# %% [markdown]
# data_scientist

# %% [markdown]
# if you match 'data scientist' AND NOT 'data analyst' AND NOT 'data engineer':
#     then newpos.append(1)
# if you match 'data analyst' AND NOT 'data scientist' AND NOT 'data engineer':
#      then newpos.append(2)
# if you match 'data engineer' AND NOT 'data scientist' AND NOT 'data analyst':
#      then newpos.append(3)
# if you match 'machine learning' AND NOT 'data engineer' AND NOT 'data scientist' AND NOT 'data analyst':
#      then newpos.append(3)

# %% [markdown]
# data_analyst = df1[df1['position'].str.contains('data analyst')]
# data_engineer = df1[df1['position'].str.contains('data engineer')]
# machine_learning = df1[df1['position'].str.contains('data engineer')]
#
#
# data_scientist.info()
# data_scientist['position'].unique()

# %% [markdown]
# data_analyst.info()

# %%
data_engineer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 187 to 962
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     31 non-null     object
#  1   company      31 non-null     object
#  2   description  31 non-null     object
#  3   numreview    21 non-null     object
#  4   location     31 non-null     object
# dtypes: object(5)
# memory usage: 1.5+ KB

# %%
df1.loc[df1['position'].str.contains('data_scientist|machine_learning|statistician'), 'data_scientist']=1
df1.loc[df1['position'].str.contains('data_analyst|data_analytics|_analytics|quantitative_analyst'), 'data_analyst']=1
df1.loc[df1['position'].str.contains('data_engineer|data_science_engineer|quantitative_data_engineer'), 'data_engineer']=1

# %%
df1
# Out:
#                                               position  \
# 0    data_scientist—research_(ref_#_exec/rd_dat_nyc...
# 1                    data_scientist/pre_sales_engineer
# 2                      data_analyst/research_scientist
# 3                                       data_scientist
# 4                                       data_scientist
# ..                                                 ...
# 981                                     data_scientist
# 982                              junior_data_scientist
# 983                       data_scientist_(entry-level)
# 984                                     data_scientist
# 985               junior_data_scientist_apprenticeship
#
#                                                company  \
# 0    New York State Office of the Attorney General ...
# 1                                              Celonis
# 2                   Columbia University Medical Center
# 3                                     fractalanalytics
# ...

# %%
df1['data_scientist']= df1['data_scientist'].fillna(0)
df1['data_analyst']= df1['data_analyst'].fillna(0)
df1['data_engineer']= df1['data_engineer'].fillna(0)
df1
# Out:
#                                               position  \
# 0    data_scientist—research_(ref_#_exec/rd_dat_nyc...
# 1                    data_scientist/pre_sales_engineer
# 2                      data_analyst/research_scientist
# 3                                       data_scientist
# 4                                       data_scientist
# ..                                                 ...
# 981                                     data_scientist
# 982                              junior_data_scientist
# 983                       data_scientist_(entry-level)
# 984                                     data_scientist
# 985               junior_data_scientist_apprenticeship
#
#                                                company  \
# 0    New York State Office of the Attorney General ...
# 1                                              Celonis
# 2                   Columbia University Medical Center
# 3                                     fractalanalytics
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.to_excel(r'df1_NY.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-f741e8ed100a> in <module>
# ----> 1 df1.to_excel(r'df1_NY.xlsx', index=False)
#
# ~\anaconda3\envs\ClassFede1\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2355             inf_rep=inf_rep,
#    2356         )
# -> 2357         formatter.write(
#    2358             excel_writer,
#    2359             sheet_name=sheet_name,
#
# ~\anaconda3\envs\ClassFede1\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
# ...
